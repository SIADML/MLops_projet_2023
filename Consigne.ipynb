# %% [markdown]
# ML Ops

# %% [markdown]
#     -Livrable attendus
#         -Code sur GitHub (collaboration)
#         -Rapport
#             Introduction
#             Description données
#             Détails modèle + choix
#             Les performances
#             Conclusion
#        - Mail du groupe
#             Le jeu de donnée/ Lien
#             l’équipe
#             Rapport Pdf
#             Repo Github (public ?)

# %% [markdown]
#     -Projet groupe (2 à 4 max)
#         -Choix du jeu de données (régression, classification, app square ?)
#             Créer les notebook d’expérimentation
#                 -> séparer note bock de code et expérimentation mais conserver les deux
#             Écrire un code structuré & package

# %% [markdown]
# 			ex: foodcast du tp_mlflow)

# %% [markdown]
#        - Evaluer les performances du modèle avec les métriques adaptées
#        - Bonus :
#             Implémentation de mlflow
#             Implémentation d’une cicd

# %% [markdown]
# N’oubliez pas :

# %% [markdown]
#     De documenter vos fonctions
#     Créer un fichier condamné.yaml (cf tp??? Ou requirements.txt contenant la liste des package & version utilisées)
#     Poussez votre code sur une plateforme collaborative git (ex GitHub)
#     Écrire quelque tests unitaire (pytest)

# %% [markdown]
# Deadline : 23 décembre

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=029b32ea-4b45-4aac-a053-fdf34162e9b0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
